# %%
# !pip install RISE
# !pip install bokeh
# !pip install jupyter_contrib_nbextensions
# !jupyter_contrib_nbextensions install --system
# !pip install jupyter_contrib_nbextensions 
# !jupyter contrib nbextension install --system
# Out:
# ...
# [I 01:30:13 InstallContribNbextensionsApp] jupyter contrib nbextension install --system
# [I 01:30:13 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 01:30:13 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 01:30:13 InstallContribNbextensionsApp] Making directory: /usr/local/share/jupyter/nbextensions/scratchpad/
# [I 01:30:13 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad/demo.gif -> /usr/local/share/jupyter/nbextensions/scratchpad/demo.gif
# [I 01:30:13 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad/LICENSE -> /usr/local/share/jupyter/nbextensions/scratchpad/LICENSE
# ...

# %%
# !jupyter contrib nbextension install --nbextensions InstallContribNbextensionsApp.nbextensions_dir
# Out:
# [I 01:30:19 InstallContribNbextensionsApp] jupyter contrib nbextension install --nbextensions InstallContribNbextensionsApp.nbextensions_dir
# [I 01:30:19 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 01:30:19 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 01:30:19 InstallContribNbextensionsApp] Making directory: InstallContribNbextensionsApp.nbextensions_dir/scratchpad/
# [I 01:30:19 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad/demo.gif -> InstallContribNbextensionsApp.nbextensions_dir/scratchpad/demo.gif
# ...

# %%
# !jupyter contrib nbextension install --system
# Out:
# [I 01:30:24 InstallContribNbextensionsApp] jupyter contrib nbextension install --system
# [I 01:30:24 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 01:30:24 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 01:30:24 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/scratchpad/demo.gif
# [I 01:30:24 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/scratchpad/LICENSE
# [I 01:30:24 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/scratchpad/README.md
# [I 01:30:24 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/scratchpad/main.js
# [I 01:30:24 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/scratchpad/scratchpad.css
# ...

# %%
# !pip install pyngrok --quiet
# Out:
#      |████████████████████████████████| 745 kB 5.2 MB/s
# ...

# %%
from pyngrok import ngrok

# terminal open tunnels if exist
ngrok.kill()

# Setting the authtoken(optional)
# Get yout atuhtoken from https://dashboard.ngrok.com/auth
NGROK_AUTH_TOKEN = ""
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# %%
get_ipython().system_raw('jupyter notebook --ip=0.0.0.0 --port=14000 &')

# %%
ngrok.connect(14000)
# Out:
# <NgrokTunnel: "http://d3fc-35-239-188-128.ngrok.io" -> "http://localhost:14000">
